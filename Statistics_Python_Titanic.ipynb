# %% [markdown]
# <a href="https://colab.research.google.com/github/astridcvr/titanic-descriptive-analysis/blob/main/Statistics_Python_Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚢 Titanic Dataset – Descriptive Statistics Analysis
# _A mini data exploration project by Astrid Villalobos_
#
# **Weekend Project | Python + Pandas + Seaborn | Google Colab**
#
# ---
#
# ## Project Goals
#
# - Practice descriptive statistics using a real dataset
# - Explore the relationship between age, fare, and passenger class
# - Apply key concepts: mean, median, mode, standard deviation, variance
# - Visualize distributions using histograms and boxplots
#
# ---
#
# ## Dataset
#
# The Titanic dataset is available via Seaborn's built-in datasets. It contains information about passengers on the Titanic, including survival status, age, fare, class, and family relationships.
#
# ---
#
# ## Summary of Findings
#
# - First-class passengers were generally older (avg. age ~38), while third-class passengers were younger (avg. age ~25)
# - Fare amounts strongly correlated with class: higher in first class
# - The dataset includes 891 passengers, with 714 valid age records
# - Ages range from ~0.42 to 80 years; most passengers were between 20 and 38
# - Standard deviation in age was ~14.5, showing high variability
#
# ---
#
# ✅ This project helped reinforce statistical thinking and real-world data analysis using Python.

# %% [markdown]
# # Descriptive Statistics with Python
#
# This notebook will guide you through basic descriptive statistics using the Titanic dataset from Seaborn. We will calculate measures of central tendency, dispersion, and visualize distributions to practice statistical thinking and Python coding skills.

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load and Inspect the Titanic Dataset

# %%
# Load dataset
df = sns.load_dataset('titanic')

# View the first few rows
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['class', 'deck'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['embarked'].value_counts()
    for x_label, grp in _df_20.groupby('sex')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('sex')
_ = plt.ylabel('embarked')

# %% [markdown]
# ## Descriptive Statistics

# %%
df['age'].isnull().sum()
# Out:
# np.int64(177)

# %%
# Summary statistics
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Mean, Median, Mode for Age
print('Mean age:', df['age'].mean())
print('Median age:', df['age'].median())
print('Mode age:', df['age'].mode().values)
# Out:
# Mean age: 29.69911764705882
# Median age: 28.0
# Mode age: [24.]

# %%
# Minimum Age, Maximum Age, Age Range
print('Minimum age:', df['age'].min())
print('Maximum age:', df['age'].max())
print('Age range:', df['age'].max() - df['age'].min())
# Out:
# Minimum age: 0.42
# Maximum age: 80.0
# Age range: 79.58

# %%
# Standard Deviation, Variance, Range
print('Standard Deviation:', df['age'].std())
print('Variance:', df['age'].var())
print('Range:', df['age'].max() - df['age'].min())
# Out:
# Standard Deviation: 14.526497332334044
# Variance: 211.0191247463081
# Range: 79.58

# %% [markdown]
# ## Visualizations

# %%
# Histogram and KDE for Age
sns.histplot(df['age'].dropna(), bins=20, kde=True)
plt.title('Age Distribution')
plt.show()

# %%
# Boxplot for Age
sns.boxplot(x=df['age'])
plt.title('Age Boxplot')
plt.show()

# %% [markdown]
# ## Mini Project: Class vs Age and Fare

# %%
# Average Age and Fare by Pclass
df.groupby('pclass')[['age', 'fare']].mean()
# Out:
#               age       fare
# pclass
# 1       38.233441  84.154687
# 2       29.877630  20.662183
# 3       25.140620  13.675550
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_40['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_41['fare'].plot(kind='hist', bins=20, title='fare')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_42.plot(kind='scatter', x='age', y='fare', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
# ...

# %%
# Boxplots for Age and Fare by Class
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns.boxplot(x='pclass', y='age', data=df, ax=axes[0])
axes[0].set_title('Age by Passenger Class')

sns.boxplot(x='pclass', y='fare', data=df, ax=axes[1])
axes[1].set_title('Fare by Passenger Class')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusions
#
# **- What can you say about the age distribution per class?**
# * We can observe the age distribution per class using the box plot. It’s notable that first-class passengers tend to be older, with an average age of around 38 years. In second class, the average age is lower at approximately 29 years. Finally, third-class passengers form the youngest group, with an average age of 25 years. This indicates a trend where younger individuals were more likely to travel in third class, while older passengers were more represented in first class.
#
#
#
# **- Are fares higher for a specific class?**
# * Yes. The average fare by class is approximately 84, 20, and 13 for first, second, and third class respectively. This clearly shows that first-class passengers paid significantly higher fares, followed by a steep drop for second class and an even lower average for third class.
#
#
#
# **- Write your summary and observations here.**
# * The dataset contains 891 passengers, with age information available for 714 of them.
# * The mean age is 29.7 years.
# * The youngest passenger is approximately 0.42 years old, and the oldest is 80, giving a wide age range of 79.58 years.
# * The standard deviation is 14.5, meaning most passengers are within 15 years above or below the average.
# * Based on the interquartile range (Q1 = 20, Q3 = 38), the majority of passengers were between 20 and 38 years old, which matches the earlier observation that most were young to middle-aged.
# * The age distribution varies by class, with older passengers concentrated in first class and younger ones in third class.
# Fares strongly correlate with class, with significantly higher values in first class.
#
# ```
# # This is formatted as code
# ```
